# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
pos_list = [[0,-98,25],
                [20,-98,25],
                [40,-98,25],
                [60,-98,25],
                [80,-98,25],
                [100,-98,25],
                [120,-98,25],
                [140,-98,25],
                [160,-98,25],
                [180,-98,25],
                [200,-98,25],
                [210,-98,25],
                [220,-97,15],
                [230,-95,15],
                [240,-92,15],
                [250,-87,15],
                [260,-81,15],
                [270,-74,15],
                [280,-63,15],
                [290,-49,15],
                [295,-37,15],
                [300,-22,15],
                [303,-5,15],
                [303,15,25],
                [303,35,25],
                [303,50,25],
                [301,63,15],
                [295,77,15],
                [290,83,15],
                [285,87,15],
                [280,90,15],
                [275,93,15],
                [270,94.5,15],
                [250,96.5,15],
                [240,96.5,25],
                [230,96.5,25],
                [220,96.5,25],
                [210,96.5,25],
                [160,96.5,25],
                [110,96.5,25],
                [60,96.5,25],
                [50,96.5,25],
                [40,99,15],
                [40,99,15],
                [30,103,15],
                [20,109,15],
                [15,115,15],
                [15,115,15],
                [9,125,15],
                [5,135,15],
                [4,145,15],
                [3,157,15],
                [-0.5,170,15],
                [-7,180,15],
                [-14,186.5,15],
                [-29,194,15],
                [-45,197,15],
                [-56.5,194.5,15],
                [-65.5,191.5,15],
                [-81.5,177.5,15],
                [-87,169.5,15],
                [-90,160,15],
                [-92,152,15],
                [-97.5,123.5,15],
                [-104.5,113,15],
                [-118,103,15],
                [-144,96.5,15],
                [-167,91,15],
                [-180.5,79,15],
                [-187,68.5,15],
                [-191,53,15],
                [-191,33,25],
                [-191,13,25],
                [-191,-3,25],
                [-189,-20,15],
                [-184.5,-34.5,15],
                [-178.5,-50.5,15],
                [-166.5,-66,15],
                [-150,-80.5,15],
                [-138.5,-87.5,15],
                [-125,-93.5,15],
                [-113.5,-96.5,15],
                [-96,-98,25],
                [-76,-98,25],
                [-56,-98,25],
                [-36,-98,25],
                [-16,-98,25],
                ]
# print(pos_list[0])
wx = []
wy = []
for el in pos_list:
    wx.append(el[0])
    wy.append(el[1])

file = open(r"C:\Users\STP\Documents\data.txt", "r")
lines = file.readlines()
file.close() 
x = lines[0::2]
y = lines[1::2]
x = x[0::200]
y = y[0::200]
xx = []
yy = []
for el in x:
    xx.append(int(float(el)))
for el in y:
    yy.append(int(float(el)))
print(len(x))
plt.figure(figsize=(14,8))
# plt.style.use('Solarize_Light2')
plt.title("Trajectory and Waypoint Graphs")
plt.plot(xx,yy)

label_x = -20
label_y = -70
arrow_x = 0
arrow_y = -98
arrow_properties = dict(
    facecolor="black", width=0.5,
    headwidth=4, shrink=0.1)

plt.annotate(
    "Start/End Point", xy=(arrow_x, arrow_y),
    xytext=(label_x, label_y),
    arrowprops=arrow_properties)
plt.scatter(wx,wy, marker="x", color="red")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
# Out:
# 73
